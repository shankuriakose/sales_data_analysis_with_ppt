# %%
# !gdown 1sOvvVvbIKqtAN-GO595gPno6XNeKxRBy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1sOvvVvbIKqtAN-GO595gPno6XNeKxRBy
# To: /Users/shankuriakose/Desktop/DataAnalysis/Analysis_DA/datasets_435_896_sales_data_sample.csv
# 100%|████████████████████████████████████████| 528k/528k [00:00<00:00, 3.86MB/s]

# %%
import pandas as pd

# %%
df = pd.read_csv("datasets_435_896_sales_data_sample.csv", encoding='latin-1')
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
cols = ['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
       'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
       'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
       'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
       'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
       'DEALSIZE']

object_cols = ["STATUS","PRODUCTLINE","PRODUCTCODE","CUSTOMERNAME",'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
       'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME','DEALSIZE']



cols_to_display = df.columns[6:]  # Select columns 7 to 17

# Display the selected columns using df.head()
df[cols_to_display].head()
# Out:
#     STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  Shipped       1         2     2003  Motorcycles    95    S10_1678
# 1  Shipped       2         5     2003  Motorcycles    95    S10_1678
# 2  Shipped       3         7     2003  Motorcycles    95    S10_1678
# 3  Shipped       3         8     2003  Motorcycles    95    S10_1678
# 4  Shipped       4        10     2003  Motorcycles    95    S10_1678
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0         Land of Toys Inc.        2125557818        897 Long Airport Avenue
# 1        Reims Collectables        26.47.1555             59 rue de l'Abbaye
# 2           Lyon Souveniers  +33 1 46 62 7555  27 rue du Colonel Pierre Avia
# 3         Toys4GrownUps.com        6265557265             78934 Hillside Dr.
# 4  Corporate Gift Ideas Co.        6505551386                7734 Strong St.
#
#   ADDRESSLINE2           CITY STATE POSTALCODE COUNTRY TERRITORY  \
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
object_cols = ["STATUS", "PRODUCTLINE", "PRODUCTCODE", "CUSTOMERNAME", 'ADDRESSLINE1', 'ADDRESSLINE2', 
               'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 
               'CONTACTFIRSTNAME', 'DEALSIZE']

def convert_columns_to_int(df, column_list):
    for column in column_list:
        # Check if the column is present in the DataFrame before attempting conversion
        if column in df.columns:
            # Try to convert the column to integers, replace non-numeric values with NaN
            df[column] = pd.to_numeric(df[column], errors='coerce')
            
            # If there are NaN values after conversion, you can fill them with a specific value
            # For example, you can fill NaN values with 0
            df[column].fillna(0, inplace=True)
            
            # Convert the column to integer type
            df[column] = df[column].astype(int)
    
    return df

# Example usage:
# Assuming 'df' is your DataFrame
df = convert_columns_to_int(df, object_cols)

# %%
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE1  \
# 0   2/24/2003 0:00       0       1         2     2003  ...             0
# 1    5/7/2003 0:00       0       2         5     2003  ...             0
# 2    7/1/2003 0:00       0       3         7     2003  ...             0
# 3   8/25/2003 0:00       0       3         8     2003  ...             0
# 4  10/10/2003 0:00       0       4        10     2003  ...             0
#
#    ADDRESSLINE2  CITY  STATE POSTALCODE  COUNTRY  TERRITORY  CONTACTLASTNAME  \
# ...

# %%
cols_to_display = df.columns[6:]
df[cols_to_display].head()
# Out:
#    STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  PRODUCTCODE  \
# 0       0       1         2     2003            0    95            0
# 1       0       2         5     2003            0    95            0
# 2       0       3         7     2003            0    95            0
# 3       0       3         8     2003            0    95            0
# 4       0       4        10     2003            0    95            0
#
#    CUSTOMERNAME             PHONE  ADDRESSLINE1  ADDRESSLINE2  CITY  STATE  \
# 0             0        2125557818             0             0     0      0
# 1             0        26.47.1555             0             0     0      0
# 2             0  +33 1 46 62 7555             0             0     0      0
# 3             0        6265557265             0             0     0      0
# 4             0        6505551386             0             0     0      0
#
#    POSTALCODE  COUNTRY  TERRITORY  CONTACTLASTNAME  CONTACTFIRSTNAME  DEALSIZE
# ...

# %%
object_cols = ["STATUS", "PRODUCTLINE", "PRODUCTCODE", "CUSTOMERNAME", 'ADDRESSLINE1', 'ADDRESSLINE2', 
               'CITY', 'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 
               'CONTACTFIRSTNAME', 'DEALSIZE']

def convert_columns_to_int(df, column_list):
    for column in column_list:
        # Check if the column is present in the DataFrame and has a numeric dtype
        if column in df.columns and pd.api.types.is_numeric_dtype(df[column]):
            # Try to convert the column to integers, replace non-numeric values with NaN
            df[column] = pd.to_numeric(df[column], errors='coerce')
            
            # If there are NaN values after conversion, you can fill them with a specific value
            # For example, you can fill NaN values with 0
            df[column].fillna(0, inplace=True)
            
            # Convert the column to integer type
            df[column] = df[column].astype(int)
    
    return df

# Example usage:
# Assuming 'df' is your DataFrame
df = convert_columns_to_int(df, object_cols)

# %%
df.head(10)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
import pandas as pd
df = pd.read_csv("datasets_435_896_sales_data_sample.csv", encoding='latin-1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
def data_preprocessing(df):

    # columns_to_drop=['postalcode', 'addressline2', 'phone', 
    #                  'productcode', 'msrp', 'contactfirstname', 
    #                  'contactlastname', 'qtr_id', 'orderlinenumber']
    df.columns= df.columns.str.lower()
    df.sort_values(by=['ordernumber'])
    df['orderdate'] = pd.to_datetime(df['orderdate'])
    # df.drop(columns_to_drop, axis=1,inplace= True)
    df['territory'] = df['territory'].fillna('NAM') ## imputing teritory "nam"
    df = df[~((df['status'] == 'Cancelled') | (df['status'] == 'On Hold'))] ## remove the canceled and pending cols
    
    return df


def categorize_columns(df):
    numeric_fields = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
    object_fields = df.select_dtypes(include='object').columns.tolist()
    date_fields = df.select_dtypes(include="datetime64").columns.tolist()

    print("Numeric Fields:", numeric_fields)
    print("Object Fields:", object_fields)
    print("Date Fields:", date_fields)

    
    return numeric_fields, object_fields, date_fields


def missing_cols_percent():
    ## cols with missing values
    missing_percentages = (sales.isnull().mean() * 100).round(2)
    
    missing_columns = missing_percentages[missing_percentages > 0].index.tolist()
    
    print("Columns with missing values:")
    for column in missing_columns:
        print(f"{column}: {missing_percentages[column]}%")

# %%
pwd
# Out:
# '/Users/shankuriakose/Desktop/DataAnalysis/Analysis_DA'

# %%
df = data_preprocessing(df)
csv_file_path = "/Users/shankuriakose/Desktop/DataAnalysis/Analysis_DA/sales_processed.csv"

# Save the DataFrame to CSV
df.to_csv(csv_file_path, index=False)
